# %% [markdown]
# # DOWNLOAD SEER DATA:
#
# TODO

# %% [markdown]
# # INCIDENTS

# %% [markdown]
# # GET THE TABLE INFO

# %% [markdown]
# ## la manera más facil

# %%
pd.read_sas("../data/external/seerseer/incidence/read.seer.research.nov2010.sas")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-2cf07689752f> in <module>()
# ----> 1 pd.read_sas("../data/external/seerseer/incidence/read.seer.research.nov2010.sas",format='xport')
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/io/sas/sasreader.pyc in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator)
#      54         reader = XportReader(filepath_or_buffer, index=index,
#      55                              encoding=encoding,
# ---> 56                              chunksize=chunksize)
#      57     elif format.lower() == 'sas7bdat':
#      58         from pandas.io.sas.sas7bdat import SAS7BDATReader
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/io/sas/sas_xport.pyc in __init__(self, filepath_or_buffer, index, encoding, chunksize)
#     242
#     243         if isinstance(filepath_or_buffer, (str, compat.text_type, bytes)):
# --> 244             self.filepath_or_buffer = open(filepath_or_buffer, 'rb')
#     245         else:
#     246             # Copy to BytesIO, and ensure no encoding
#
# IOError: [Errno 2] No such file or directory: '../data/external/seerseer/incidence/read.seer.research.nov2010.sas'

# %% [markdown]
# ## si no funciona...

# %%
import pandas as pd

# %%
columns_file = "../src/data/aux/tabula-seerdic-7-9.csv"

# %%
columns_locations = pd.read_csv(columns_file, sep=";")
columns_locations.head()
# Out:
#                  Item Name Positions  Length
# 0        Patient ID number       1-8       8
# 1              Registry ID      9-18      10
# 2     Marital Status at DX     19-19       1
# 3           Race/Ethnicity     20-21       2
# 4  Spanish/Hispanic Origin     22-22       1

# %%
import re

# %%
list_of_rows = []
for index, row in columns_locations.iterrows():
    a_row = [row[0]]
    a_row.append(int(row[1].split("-")[0]))
    a_row.append(int(row[1].split("-")[1]))
    a_row.append(int(row[2]))
    list_of_rows.append(a_row)

columns = ['Name', 'Init', 'End', 'Length']
columns_locations_split = pd.DataFrame(list_of_rows, columns=columns)

# %%
columns_locations_split
# Out:
#                                             Name  Init  End  Length
# 0                              Patient ID number     1    8       8
# 1                                    Registry ID     9   18      10
# 2                           Marital Status at DX    19   19       1
# 3                                 Race/Ethnicity    20   21       2
# 4                        Spanish/Hispanic Origin    22   22       1
# 5                   NHIA Derived Hispanic Origin    23   23       1
# 6                                            Sex    24   24       1
# 7                               Age at diagnosis    25   27       3
# 8                                  Year of Birth    28   31       4
# 9                                    Birth Place    32   34       3
# 10                      Sequence Number--Central    35   36       2
# 11                            Month of diagnosis    37   38       2
# 12                             Year of diagnosis    39   42       4
# 13                                  Primary Site    43   46       4
# 14                                    Laterality    47   47       1
# 15                     Histology (92-00) ICD-O-2    48   51       4
# 16                      Behavior (92-00) ICD-O-2    52   52       1
# 17                       Histologic Type ICD-O-3    53   56       4
# 18                         Behavior Code ICD-O-3    57   57       1
# 19                                         Grade    58   58       1
# 20                       Diagnostic Confirmation    59   59       1
# 21                      Type of Reporting Source    60   60       1
# 22                                EOD—Tumor Size    61   63       3
# 23                                 EOD—Extension    64   65       2
# 24                      EOD—Extension Prost Path    66   67       2
# 25                         EOD—Lymph Node Involv    68   68       1
# 26                       Regional Nodes Positive    69   70       2
# 27                       Regional Nodes Examined    71   72       2
# 28                              EOD—Old 13 Digit    73   85      13
# 29                               EOD—Old 2 Digit    86   87       2
# ..                                           ...   ...  ...     ...
# 94             ICCC site recode extended ICD-O-3   221  223       3
# 95                  Behavior Recode for Analysis   224  224       1
# 96                           ICD-O Coding Scheme   225  225       1
# 97              Histology Recode—Broad Groupings   226  227       2
# 98              Histology Recode—Brain Groupings   228  229       2
# 99                               CS Schema v0202   230  232       3
# 100            Race recode (White, Black, Other)   233  233       1
# 101                  Race recode (W, B, AI, API)   234  234       1
# 102      Origin recode NHIA (Hispanic, Non-Hisp)   235  235       1
# 103                        SEER historic stage A   236  236       1
# 104           AJCC stage 3rd edition (1988-2003)   237  238       2
# 105  SEER modified AJCC Stage 3rd ed (1988-2003)   239  240       2
# 106          SEER Summary Stage 1977 (1995-2000)   241  241       1
# 107          SEER Summary Stage 2000 (2001-2003)   242  242       1
# 108                          Number of primaries   243  244       2
# 109            First malignant primary indicator   245  245       1
# 110                          State-county recode   246  250       5
# 111                         Survival time recode   251  254       4
# 112           Cause of Death to SEER site recode   255  259       5
# 113                           COD to site rec KM   260  264       5
# 114                          Vital Status recode   265  265       1
# 115                                     IHS Link   266  266       1
# 116                   Summary stage 2000 (1998+)   267  267       1
# 117                              AYA site recode   268  269       2
# 118                      Lymphoma subtype recode   270  271       2
# 119     SEER Cause-Specific Death Classification   272  272       1
# 120     SEER Other Cause of Death Classification   273  273       1
# 121                       CS Tumor Size/Ext Eval   274  274       1
# 122                          CS Lymph Nodes Eval   275  275       1
# 123                                 CS Mets Eval   276  276       1
#
# [124 rows x 4 columns]

# %%
import os

# %%
root = "../data/external/seer/incidence"
files = ['BREAST.TXT',
         'COLRECT.TXT',
         'DIGOTHR.TXT',
         'FEMGEN.TXT',
         'LYMYLEUK.TXT',
         'MALEGEN.TXT',
         'OTHER.TXT',
         'RESPIR.TXT',
         'URINARY.TXT']

folders = ['yr1992_2008.sj_la_rg_ak',
           'yr2005.lo_2nd_half',
           'yr1973_2008.seer9',
           'yr2000_2008.ca_ky_lo_nj',]

# %%
def my_files(root=root, files=files, folders=folders):
    hahahaha = []
    for i in folders:
        for f in files:
            hahahaha.append( os.path.join(root,i,f) )
    return hahahaha

# %%
fs = my_files()[0]
fs
# Out:
# '../data/external/seer/incidence/yr1992_2008.sj_la_rg_ak/BREAST.TXT'

# %%
str_rows = []
for i,r in pd.read_csv(fs, header= None).iterrows():
    str_rows.append(r[0])

# %%
len(str_rows)
# Out:
# 140829

# %%
df_rows = pd.DataFrame(str_rows)

# %%
def split_seer(row):
    return [row[elem['Init']: elem['End']] for k, elem in columns_locations_split.iterrows()]

# %%
df_rows.columns = ['record']

# %%
df_rows.head()
# Out:
#                                               record
# 0  570000150000001537201002058194804502052007C509...
# 1  570001730000001537501002085191103302091996C506...
# 2  570002790000001537502002068192403302121992C504...
# 3  570007650000001537401002062193603303091998C505...
# 4  570011290000001537502002062194201102102004C509...

# %%
df2 = df_rows.record.apply(split_seer)

# %%
df2.head()
# Out:
# 0    [7000015, 000001537, , 1, , , , 58, 948, 45, 2...
# 1    [7000173, 000001537, , 1, , , , 85, 911, 33, 2...
# 2    [7000279, 000001537, , 2, , , , 68, 924, 33, 2...
# 3    [7000765, 000001537, , 1, , , , 62, 936, 33, 3...
# 4    [7001129, 000001537, , 2, , , , 62, 942, 11, 2...
# Name: record, dtype: object

# %%
res = df_rows.apply(split_seer)

# %%
res.head()
# Out:
# 0    [7000015, 000001537, , 1, , , , 58, 948, 45, 2...
# dtype: object

# %%
columns_names = columns_locations_split['Name']
list_of_columns = []
for r in str_rows:
    columns = []
    for k,elem in columns_locations_split.iterrows():
        start = elem['Init']
        end = elem['End']
        columns.append(r[start:end])
    list_of_columns.append(columns)
df_columns = pd.DataFrame(columns, columns=columns_names)
df_columns.to_csv(re.sub())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-bd34894b331b> in <module>()
#       3 for r in str_rows:
#       4     columns = []
# ----> 5     for k,elem in columns_locations_split.iterrows():
#       6         start = elem['Init']
#       7         end = elem['End']
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/core/frame.pyc in iterrows(self)
#     773         klass = self._constructor_sliced
#     774         for k, v in zip(self.index, self.values):
# --> 775             s = klass(v, index=columns, name=k)
#     776             yield k, s
#     777
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     278         generic.NDFrame.__init__(self, data, fastpath=True)
#     279
# --> 280         self.name = name
#     281         self._set_axis(0, index, fastpath=True)
#     282
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __setattr__(self, name, value)
#    4382
#    4383         try:
# -> 4384             object.__getattribute__(self, name)
#    4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/core/series.pyc in name(self)
#     400     @property
#     401     def name(self):
# --> 402         return self._name
#     403
#     404     @name.setter
#
# /home/alabarga/NavarraBiomed/ONCONET/codigo/.hackcancer_env/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4364         # calling obj.__getattr__('x').
#    4365
# -> 4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
#    4368             return object.__getattribute__(self, name)
#
# KeyboardInterrupt:

# %%
df_columns = pd.DataFrame(list_of_columns, columns=columns_names)
dest = re.sub(".TXT", ".csv", fs) #"{}.csv".format(file)
df_columns.to_csv(dest)
dest
# Out:
# 'seer/incidence/yr1992_2008.sj_la_rg_ak/BREAST.csv'

# %%
columns_names = columns_locations_split['Name']


def to_csv(file, dest=None):
    #Around 25 mins per txt file.
    str_rows = []
    for i,r in pd.read_csv(file, header= None).iterrows():
        str_rows.append(r[0])
    
    list_of_columns = []
    for r in str_rows:
        columns = []
        for k,elem in columns_locations_split.iterrows():
            start = elem['Init']
            end = elem['End']
            columns.append(str_rows[0][start:end])
        list_of_columns.append(columns)
    df_columns = pd.DataFrame(list_of_columns, columns=columns_names)
    
    try:
        dest
    except:
        dest = re.sub(".txt", ".csv", file) #"{}.csv".format(file)
    df_columns.to_csv(dest)
    return dest

# %%
to_csv(my_files()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-13b2018838af> in <module>()
# ----> 1 to_csv(my_files()[0])
#
# <ipython-input-92-94fb5f5bc0e0> in to_csv(file, dest)
#      11     for r in str_rows:
#      12         columns = []
# ---> 13         for k,elem in columns_locations_split.iterrows():
#      14             start = elem['Init']
#      15             end = elem['End']
#
# ~/anaconda/envs/hackcancer/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#     696         klass = self._constructor_sliced
#     697         for k, v in zip(self.index, self.values):
# --> 698             s = klass(v, index=columns, name=k)
#     699             yield k, s
#     700
#
# ~/anaconda/envs/hackcancer/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     246             else:
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#     250                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/anaconda/envs/hackcancer/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2950             subarr = _sanitize_index(data, index, copy=True)
#    2951         else:
# -> 2952             subarr = _try_cast(data, True)
#    2953
#    2954         if copy:
#
# ~/anaconda/envs/hackcancer/lib/python3.6/site-packages/pandas/core/series.py in _try_cast(arr, take_fast_path)
#    2917
#    2918         try:
# -> 2919             subarr = maybe_cast_to_datetime(arr, dtype)
#    2920             if not is_extension_type(subarr):
#    2921                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# ~/anaconda/envs/hackcancer/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_datetime(value, dtype, errors)
#     973         # conversion
#     974         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
# --> 975                                     value.dtype == np.object_)):
#     976             value = maybe_infer_to_datetimelike(value)
#     977
#
# KeyboardInterrupt:
